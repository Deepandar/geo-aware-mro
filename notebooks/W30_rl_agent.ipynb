# %% [markdown]
# # Week 30: RL Reorder Agent
# Evaluating PPO vs Newsvendor Baselines.

# %%
from src.rl.rl_reorder_agent import PPOReorderAgent
agent = PPOReorderAgent(total_timesteps=1000)
agent.train()
